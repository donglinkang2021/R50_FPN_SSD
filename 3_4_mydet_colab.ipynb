# %% [markdown]
# # Resnet50+FPN+SSD
#
# 自己从头到尾手写的第一个模型，在colab上测试一下效果

# %% [markdown]
# ## 配置环境

# %%
# !nvidia-smi
# Out:
# Tue Jul  4 14:37:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 上传自己写的包后解压
# !unzip lastwork.zip

# %%
# !rm lastwork.zip
# Out:
# rm: cannot remove 'lastwork.zip': No such file or directory

# %% [markdown]
# ## 挂载google硬盘获取数据

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip drive/MyDrive/dl_detection.zip

# %% [markdown]
# > 花了2min52s来解压google drive中的数据

# %% [markdown]
# ## 加载数据

# %%
from utils.data import read_Cocodata_train, show_sample
Cocodata_train = read_Cocodata_train(is_transform = False)
show_sample(Cocodata_train, 0)
# Out:
# loading annotations into memory...
# Done (t=0.70s)
# creating index...
# index created!

# %%
Cocodata_train = read_Cocodata_train(is_transform = True)
# Out:
# loading annotations into memory...
# Done (t=0.62s)
# creating index...
# index created!

# %%
Cocodata_train[0][0].shape, Cocodata_train[0][1].shape
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# (torch.Size([3, 256, 256]), torch.Size([50, 5]))

# %% [markdown]
# ## 定义模型

# %%
from mydet.backbone import Backbone
from mydet.neck import Neck
from mydet.head import Head
import torch

class R50_FPN_SSD(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = Backbone(model='resnet50')
        self.neck = Neck()
        self.head = Head()

    def forward(self, X):
        backbone_out = self.backbone(X)
        neck_out = self.neck(backbone_out)
        head_out = self.head(neck_out) # anchor, cls, offset
        return head_out

# %% [markdown]
# ## 设定训练参数

# %%
Cocodata_train
# Out:
# Dataset CocoDetection
#     Number of datapoints: 33354
#     Root location: ./dl_detection/train/
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=warn)
#            )
# Target transform: <function target_transform at 0x7f40793d17e0>

# %%
# 将数据集取一小部分出来，用于训练
# Cocodata_train_small = torch.utils.data.Subset(Cocodata_train, range(0, 1000))

# %% [markdown]
# ## 开始训练

# %%
from utils.device import try_gpu
from mydet.bbox.assigner import BBoxAssigner
device = try_gpu()
net = R50_FPN_SSD()
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)
num_epochs  = 5
batch_size = 128
iou_threshold = 0.5
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 为锚框分配真实边界框
bbox_assigner = BBoxAssigner(
    device = device,
    iou_threshold = iou_threshold
)

# %%
train_dataloader = torch.utils.data.DataLoader(
    Cocodata_train,
    batch_size = batch_size,
    shuffle = True
)

# %% [markdown]
# ### 训练函数

# %%
from utils.tools import Timer, Accumulator
from mydet.loss import calc_loss
from mydet.eval import cls_eval, bbox_eval

def train(net, train_dataloader, optimizer, num_epochs, device):
    net = net.to(device)
    timer = Timer()
    timer_per_batch = Timer()
    for epoch in range(num_epochs):
        # 训练精确度的和，训练精确度的和中的示例数
        # 绝对误差的和，绝对误差的和中的示例数
        metric = Accumulator(5)
        net.train()
        for features, target in train_dataloader:
            timer.start()
            timer_per_batch.start()
            optimizer.zero_grad()
            X, Y = features.to(device), target.to(device)

            # 生成多尺度的锚框，为每个锚框预测类别和偏移量
            anchors, cls_preds, bbox_preds = net(X)

            # 为每个锚框标注类别和偏移量
            bbox_labels, bbox_masks, cls_labels = bbox_assigner.multibox_target(anchors, Y)

            # 根据类别和偏移量的预测和标注值计算损失函数
            l = calc_loss(cls_preds, cls_labels,
                        bbox_preds, bbox_labels,
                        bbox_masks)

            l.mean().backward() # 这里是默认对第一个维度做平均，即对batchsize做平均

            optimizer.step()

            metric.add(
                cls_eval(cls_preds, cls_labels),
                cls_labels.numel(),
                bbox_eval(bbox_preds, bbox_labels, bbox_masks),
                bbox_labels.numel(),
                X.shape[0]
            )

            # 打印一下metric中的内容
            print(f"{epoch + 1:3d} epochs, {metric[4]:.1f} examples,"
                    f"{metric[0] / metric[1]:.2e} class acc,"
                    f"{metric[2] / metric[3]:.2e} bbox mae,"
                    f"{ X.shape[0] / timer_per_batch.stop():.1f} examples/sec on {str(device)}")

        cls_err, bbox_mae = 1 - metric[0] / metric[1], metric[2] / metric[3]

        print(f"{epoch + 1:2d}/{num_epochs:2d} epoch, \
            class error = {cls_err}, bbox mae = {bbox_mae}")

    print(f'class err {cls_err:.2e}, bbox mae {bbox_mae:.2e}')
    print(f'{len(train_dataloader.dataset) / timer.stop():.1f} examples/sec on '
        f'{str(device)}')

# %% [markdown]
# ### 开始训练

# %%
train(
    net = net,
    train_dataloader = train_dataloader,
    optimizer = optimizer,
    num_epochs = num_epochs,
    device = device
)
# Out:
#   1 epochs, 128.0 examples,2.71e-02 class acc,8.18e-02 bbox mae,21.9 examples/sec on cuda:0
#   1 epochs, 256.0 examples,5.08e-01 class acc,8.26e-02 bbox mae,47.7 examples/sec on cuda:0
#   1 epochs, 384.0 examples,6.69e-01 class acc,8.66e-02 bbox mae,37.9 examples/sec on cuda:0
#   1 epochs, 512.0 examples,7.50e-01 class acc,9.37e-02 bbox mae,47.6 examples/sec on cuda:0
#   1 epochs, 640.0 examples,7.98e-01 class acc,9.69e-02 bbox mae,48.0 examples/sec on cuda:0
#   1 epochs, 768.0 examples,8.29e-01 class acc,1.02e-01 bbox mae,38.7 examples/sec on cuda:0
#   1 epochs, 896.0 examples,8.51e-01 class acc,1.05e-01 bbox mae,48.3 examples/sec on cuda:0
#   1 epochs, 1024.0 examples,8.49e-01 class acc,1.07e-01 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 1152.0 examples,8.25e-01 class acc,1.08e-01 bbox mae,43.2 examples/sec on cuda:0
#   1 epochs, 1280.0 examples,8.42e-01 class acc,1.09e-01 bbox mae,47.7 examples/sec on cuda:0
#   1 epochs, 1408.0 examples,8.55e-01 class acc,1.08e-01 bbox mae,45.0 examples/sec on cuda:0
#   1 epochs, 1536.0 examples,8.66e-01 class acc,1.07e-01 bbox mae,47.7 examples/sec on cuda:0
#   1 epochs, 1664.0 examples,8.75e-01 class acc,1.07e-01 bbox mae,45.4 examples/sec on cuda:0
#   1 epochs, 1792.0 examples,8.83e-01 class acc,1.07e-01 bbox mae,39.6 examples/sec on cuda:0
#   1 epochs, 1920.0 examples,8.87e-01 class acc,1.06e-01 bbox mae,48.0 examples/sec on cuda:0
#   1 epochs, 2048.0 examples,8.93e-01 class acc,1.06e-01 bbox mae,47.3 examples/sec on cuda:0
#   1 epochs, 2176.0 examples,8.99e-01 class acc,1.05e-01 bbox mae,38.3 examples/sec on cuda:0
#   1 epochs, 2304.0 examples,9.04e-01 class acc,1.04e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 2432.0 examples,9.08e-01 class acc,1.03e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 2560.0 examples,9.11e-01 class acc,1.03e-01 bbox mae,43.8 examples/sec on cuda:0
#   1 epochs, 2688.0 examples,9.14e-01 class acc,1.02e-01 bbox mae,48.1 examples/sec on cuda:0
#   1 epochs, 2816.0 examples,9.15e-01 class acc,1.02e-01 bbox mae,45.4 examples/sec on cuda:0
#   1 epochs, 2944.0 examples,9.18e-01 class acc,1.01e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 3072.0 examples,9.21e-01 class acc,1.02e-01 bbox mae,48.2 examples/sec on cuda:0
#   1 epochs, 3200.0 examples,9.23e-01 class acc,1.02e-01 bbox mae,38.9 examples/sec on cuda:0
#   1 epochs, 3328.0 examples,9.26e-01 class acc,1.01e-01 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 3456.0 examples,9.28e-01 class acc,1.00e-01 bbox mae,47.6 examples/sec on cuda:0
#   1 epochs, 3584.0 examples,9.31e-01 class acc,9.95e-02 bbox mae,39.6 examples/sec on cuda:0
#   1 epochs, 3712.0 examples,9.32e-01 class acc,9.88e-02 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 3840.0 examples,9.34e-01 class acc,9.80e-02 bbox mae,47.5 examples/sec on cuda:0
#   1 epochs, 3968.0 examples,9.36e-01 class acc,9.76e-02 bbox mae,45.7 examples/sec on cuda:0
#   1 epochs, 4096.0 examples,9.37e-01 class acc,9.74e-02 bbox mae,47.6 examples/sec on cuda:0
#   1 epochs, 4224.0 examples,9.39e-01 class acc,9.67e-02 bbox mae,44.3 examples/sec on cuda:0
#   1 epochs, 4352.0 examples,9.39e-01 class acc,9.62e-02 bbox mae,47.9 examples/sec on cuda:0
#   1 epochs, 4480.0 examples,9.40e-01 class acc,9.58e-02 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 4608.0 examples,9.41e-01 class acc,9.53e-02 bbox mae,38.4 examples/sec on cuda:0
#   1 epochs, 4736.0 examples,9.43e-01 class acc,9.50e-02 bbox mae,47.4 examples/sec on cuda:0
#   1 epochs, 4864.0 examples,9.44e-01 class acc,9.48e-02 bbox mae,47.5 examples/sec on cuda:0
#   1 epochs, 4992.0 examples,9.44e-01 class acc,9.46e-02 bbox mae,39.3 examples/sec on cuda:0
#   1 epochs, 5120.0 examples,9.45e-01 class acc,9.41e-02 bbox mae,47.7 examples/sec on cuda:0
#   1 epochs, 5248.0 examples,9.46e-01 class acc,9.38e-02 bbox mae,47.3 examples/sec on cuda:0
#   1 epochs, 5376.0 examples,9.47e-01 class acc,9.36e-02 bbox mae,45.3 examples/sec on cuda:0
#   1 epochs, 5504.0 examples,9.47e-01 class acc,9.33e-02 bbox mae,45.9 examples/sec on cuda:0
#   1 epochs, 5632.0 examples,9.48e-01 class acc,9.30e-02 bbox mae,40.8 examples/sec on cuda:0
#   1 epochs, 5760.0 examples,9.49e-01 class acc,9.29e-02 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 5888.0 examples,9.50e-01 class acc,9.27e-02 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 6016.0 examples,9.51e-01 class acc,9.25e-02 bbox mae,37.8 examples/sec on cuda:0
#   1 epochs, 6144.0 examples,9.51e-01 class acc,9.23e-02 bbox mae,46.0 examples/sec on cuda:0
#   1 epochs, 6272.0 examples,9.52e-01 class acc,9.21e-02 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 6400.0 examples,9.53e-01 class acc,9.18e-02 bbox mae,41.4 examples/sec on cuda:0
#   1 epochs, 6528.0 examples,9.53e-01 class acc,9.17e-02 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 6656.0 examples,9.54e-01 class acc,9.14e-02 bbox mae,44.9 examples/sec on cuda:0
#   1 epochs, 6784.0 examples,9.55e-01 class acc,9.11e-02 bbox mae,47.3 examples/sec on cuda:0
#   1 epochs, 6912.0 examples,9.55e-01 class acc,9.08e-02 bbox mae,47.9 examples/sec on cuda:0
#   1 epochs, 7040.0 examples,9.56e-01 class acc,9.05e-02 bbox mae,39.4 examples/sec on cuda:0
#   1 epochs, 7168.0 examples,9.56e-01 class acc,9.02e-02 bbox mae,47.4 examples/sec on cuda:0
#   1 epochs, 7296.0 examples,9.57e-01 class acc,8.99e-02 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 7424.0 examples,9.58e-01 class acc,8.96e-02 bbox mae,37.9 examples/sec on cuda:0
#   1 epochs, 7552.0 examples,9.58e-01 class acc,8.93e-02 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 7680.0 examples,9.58e-01 class acc,8.91e-02 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 7808.0 examples,9.58e-01 class acc,8.88e-02 bbox mae,43.3 examples/sec on cuda:0
#   1 epochs, 7936.0 examples,9.59e-01 class acc,8.86e-02 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 8064.0 examples,9.51e-01 class acc,8.87e-02 bbox mae,43.0 examples/sec on cuda:0
#   1 epochs, 8192.0 examples,9.51e-01 class acc,8.89e-02 bbox mae,45.3 examples/sec on cuda:0
#   1 epochs, 8320.0 examples,9.46e-01 class acc,8.96e-02 bbox mae,45.2 examples/sec on cuda:0
#   1 epochs, 8448.0 examples,9.47e-01 class acc,9.04e-02 bbox mae,37.7 examples/sec on cuda:0
#   1 epochs, 8576.0 examples,9.48e-01 class acc,9.08e-02 bbox mae,45.5 examples/sec on cuda:0
#   1 epochs, 8704.0 examples,9.48e-01 class acc,9.13e-02 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 8832.0 examples,9.48e-01 class acc,9.32e-02 bbox mae,41.4 examples/sec on cuda:0
#   1 epochs, 8960.0 examples,9.49e-01 class acc,9.51e-02 bbox mae,43.6 examples/sec on cuda:0
#   1 epochs, 9088.0 examples,9.49e-01 class acc,9.69e-02 bbox mae,40.3 examples/sec on cuda:0
#   1 epochs, 9216.0 examples,9.47e-01 class acc,9.78e-02 bbox mae,44.1 examples/sec on cuda:0
#   1 epochs, 9344.0 examples,9.48e-01 class acc,9.96e-02 bbox mae,44.2 examples/sec on cuda:0
#   1 epochs, 9472.0 examples,9.47e-01 class acc,1.01e-01 bbox mae,37.7 examples/sec on cuda:0
#   1 epochs, 9600.0 examples,9.45e-01 class acc,1.02e-01 bbox mae,45.0 examples/sec on cuda:0
#   1 epochs, 9728.0 examples,9.46e-01 class acc,1.03e-01 bbox mae,45.8 examples/sec on cuda:0
#   1 epochs, 9856.0 examples,9.46e-01 class acc,1.05e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 9984.0 examples,9.47e-01 class acc,1.06e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 10112.0 examples,9.45e-01 class acc,1.09e-01 bbox mae,41.0 examples/sec on cuda:0
#   1 epochs, 10240.0 examples,9.44e-01 class acc,1.11e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 10368.0 examples,9.43e-01 class acc,1.13e-01 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 10496.0 examples,9.40e-01 class acc,1.15e-01 bbox mae,37.1 examples/sec on cuda:0
#   1 epochs, 10624.0 examples,9.40e-01 class acc,1.16e-01 bbox mae,46.0 examples/sec on cuda:0
#   1 epochs, 10752.0 examples,9.38e-01 class acc,1.18e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 10880.0 examples,9.39e-01 class acc,1.20e-01 bbox mae,41.8 examples/sec on cuda:0
#   1 epochs, 11008.0 examples,9.36e-01 class acc,1.22e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 11136.0 examples,9.37e-01 class acc,1.24e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 11264.0 examples,9.35e-01 class acc,1.26e-01 bbox mae,45.9 examples/sec on cuda:0
#   1 epochs, 11392.0 examples,9.33e-01 class acc,1.28e-01 bbox mae,44.7 examples/sec on cuda:0
#   1 epochs, 11520.0 examples,9.33e-01 class acc,1.31e-01 bbox mae,36.5 examples/sec on cuda:0
#   1 epochs, 11648.0 examples,9.29e-01 class acc,1.33e-01 bbox mae,44.3 examples/sec on cuda:0
#   1 epochs, 11776.0 examples,9.29e-01 class acc,1.35e-01 bbox mae,46.0 examples/sec on cuda:0
#   1 epochs, 11904.0 examples,9.30e-01 class acc,1.37e-01 bbox mae,40.4 examples/sec on cuda:0
#   1 epochs, 12032.0 examples,9.30e-01 class acc,1.40e-01 bbox mae,45.2 examples/sec on cuda:0
#   1 epochs, 12160.0 examples,9.30e-01 class acc,1.42e-01 bbox mae,43.1 examples/sec on cuda:0
#   1 epochs, 12288.0 examples,9.31e-01 class acc,1.43e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 12416.0 examples,9.31e-01 class acc,1.45e-01 bbox mae,45.2 examples/sec on cuda:0
#   1 epochs, 12544.0 examples,9.29e-01 class acc,1.46e-01 bbox mae,36.7 examples/sec on cuda:0
#   1 epochs, 12672.0 examples,9.30e-01 class acc,1.48e-01 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 12800.0 examples,9.30e-01 class acc,1.50e-01 bbox mae,45.7 examples/sec on cuda:0
#   1 epochs, 12928.0 examples,9.30e-01 class acc,1.51e-01 bbox mae,38.1 examples/sec on cuda:0
#   1 epochs, 13056.0 examples,9.31e-01 class acc,1.52e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 13184.0 examples,9.31e-01 class acc,1.52e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 13312.0 examples,9.29e-01 class acc,1.52e-01 bbox mae,45.9 examples/sec on cuda:0
#   1 epochs, 13440.0 examples,9.28e-01 class acc,1.53e-01 bbox mae,45.7 examples/sec on cuda:0
#   1 epochs, 13568.0 examples,9.28e-01 class acc,1.53e-01 bbox mae,39.1 examples/sec on cuda:0
#   1 epochs, 13696.0 examples,9.29e-01 class acc,1.53e-01 bbox mae,46.0 examples/sec on cuda:0
#   1 epochs, 13824.0 examples,9.29e-01 class acc,1.53e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 13952.0 examples,9.30e-01 class acc,1.53e-01 bbox mae,38.4 examples/sec on cuda:0
#   1 epochs, 14080.0 examples,9.30e-01 class acc,1.53e-01 bbox mae,46.0 examples/sec on cuda:0
#   1 epochs, 14208.0 examples,9.30e-01 class acc,1.53e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 14336.0 examples,9.31e-01 class acc,1.53e-01 bbox mae,41.1 examples/sec on cuda:0
#   1 epochs, 14464.0 examples,9.31e-01 class acc,1.53e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 14592.0 examples,9.32e-01 class acc,1.53e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 14720.0 examples,9.32e-01 class acc,1.53e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 14848.0 examples,9.33e-01 class acc,1.53e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 14976.0 examples,9.33e-01 class acc,1.52e-01 bbox mae,41.1 examples/sec on cuda:0
#   1 epochs, 15104.0 examples,9.33e-01 class acc,1.52e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 15232.0 examples,9.34e-01 class acc,1.52e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 15360.0 examples,9.34e-01 class acc,1.51e-01 bbox mae,37.9 examples/sec on cuda:0
#   1 epochs, 15488.0 examples,9.34e-01 class acc,1.51e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 15616.0 examples,9.35e-01 class acc,1.51e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 15744.0 examples,9.35e-01 class acc,1.50e-01 bbox mae,39.0 examples/sec on cuda:0
#   1 epochs, 15872.0 examples,9.35e-01 class acc,1.50e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 16000.0 examples,9.36e-01 class acc,1.49e-01 bbox mae,45.7 examples/sec on cuda:0
#   1 epochs, 16128.0 examples,9.36e-01 class acc,1.49e-01 bbox mae,45.7 examples/sec on cuda:0
#   1 epochs, 16256.0 examples,9.37e-01 class acc,1.48e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 16384.0 examples,9.37e-01 class acc,1.47e-01 bbox mae,41.2 examples/sec on cuda:0
#   1 epochs, 16512.0 examples,9.37e-01 class acc,1.47e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 16640.0 examples,9.38e-01 class acc,1.46e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 16768.0 examples,9.38e-01 class acc,1.46e-01 bbox mae,37.8 examples/sec on cuda:0
#   1 epochs, 16896.0 examples,9.38e-01 class acc,1.45e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 17024.0 examples,9.39e-01 class acc,1.44e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 17152.0 examples,9.39e-01 class acc,1.44e-01 bbox mae,40.8 examples/sec on cuda:0
#   1 epochs, 17280.0 examples,9.39e-01 class acc,1.43e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 17408.0 examples,9.40e-01 class acc,1.42e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 17536.0 examples,9.40e-01 class acc,1.42e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 17664.0 examples,9.40e-01 class acc,1.41e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 17792.0 examples,9.41e-01 class acc,1.41e-01 bbox mae,40.0 examples/sec on cuda:0
#   1 epochs, 17920.0 examples,9.41e-01 class acc,1.40e-01 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 18048.0 examples,9.41e-01 class acc,1.39e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 18176.0 examples,9.42e-01 class acc,1.39e-01 bbox mae,38.2 examples/sec on cuda:0
#   1 epochs, 18304.0 examples,9.42e-01 class acc,1.38e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 18432.0 examples,9.42e-01 class acc,1.37e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 18560.0 examples,9.42e-01 class acc,1.37e-01 bbox mae,40.8 examples/sec on cuda:0
#   1 epochs, 18688.0 examples,9.43e-01 class acc,1.36e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 18816.0 examples,9.43e-01 class acc,1.36e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 18944.0 examples,9.43e-01 class acc,1.35e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 19072.0 examples,9.44e-01 class acc,1.34e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 19200.0 examples,9.44e-01 class acc,1.34e-01 bbox mae,39.2 examples/sec on cuda:0
#   1 epochs, 19328.0 examples,9.44e-01 class acc,1.33e-01 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 19456.0 examples,9.44e-01 class acc,1.33e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 19584.0 examples,9.45e-01 class acc,1.32e-01 bbox mae,37.8 examples/sec on cuda:0
#   1 epochs, 19712.0 examples,9.45e-01 class acc,1.32e-01 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 19840.0 examples,9.45e-01 class acc,1.31e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 19968.0 examples,9.44e-01 class acc,1.31e-01 bbox mae,42.3 examples/sec on cuda:0
#   1 epochs, 20096.0 examples,9.45e-01 class acc,1.32e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 20224.0 examples,9.45e-01 class acc,1.33e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 20352.0 examples,9.45e-01 class acc,1.33e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 20480.0 examples,9.46e-01 class acc,1.34e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 20608.0 examples,9.46e-01 class acc,1.34e-01 bbox mae,40.8 examples/sec on cuda:0
#   1 epochs, 20736.0 examples,9.46e-01 class acc,1.35e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 20864.0 examples,9.46e-01 class acc,1.36e-01 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 20992.0 examples,9.47e-01 class acc,1.36e-01 bbox mae,38.2 examples/sec on cuda:0
#   1 epochs, 21120.0 examples,9.46e-01 class acc,1.37e-01 bbox mae,46.0 examples/sec on cuda:0
#   1 epochs, 21248.0 examples,9.47e-01 class acc,1.38e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 21376.0 examples,9.46e-01 class acc,1.38e-01 bbox mae,39.8 examples/sec on cuda:0
#   1 epochs, 21504.0 examples,9.46e-01 class acc,1.38e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 21632.0 examples,9.47e-01 class acc,1.39e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 21760.0 examples,9.47e-01 class acc,1.39e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 21888.0 examples,9.47e-01 class acc,1.39e-01 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 22016.0 examples,9.46e-01 class acc,1.39e-01 bbox mae,40.9 examples/sec on cuda:0
#   1 epochs, 22144.0 examples,9.47e-01 class acc,1.39e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 22272.0 examples,9.47e-01 class acc,1.39e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 22400.0 examples,9.47e-01 class acc,1.40e-01 bbox mae,38.7 examples/sec on cuda:0
#   1 epochs, 22528.0 examples,9.47e-01 class acc,1.40e-01 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 22656.0 examples,9.47e-01 class acc,1.40e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 22784.0 examples,9.47e-01 class acc,1.40e-01 bbox mae,38.4 examples/sec on cuda:0
#   1 epochs, 22912.0 examples,9.47e-01 class acc,1.41e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 23040.0 examples,9.47e-01 class acc,1.40e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 23168.0 examples,9.47e-01 class acc,1.40e-01 bbox mae,44.4 examples/sec on cuda:0
#   1 epochs, 23296.0 examples,9.48e-01 class acc,1.40e-01 bbox mae,47.4 examples/sec on cuda:0
#   1 epochs, 23424.0 examples,9.48e-01 class acc,1.40e-01 bbox mae,45.1 examples/sec on cuda:0
#   1 epochs, 23552.0 examples,9.48e-01 class acc,1.40e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 23680.0 examples,9.48e-01 class acc,1.40e-01 bbox mae,47.0 examples/sec on cuda:0
#   1 epochs, 23808.0 examples,9.48e-01 class acc,1.40e-01 bbox mae,40.7 examples/sec on cuda:0
#   1 epochs, 23936.0 examples,9.49e-01 class acc,1.39e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 24064.0 examples,9.49e-01 class acc,1.39e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 24192.0 examples,9.49e-01 class acc,1.39e-01 bbox mae,38.7 examples/sec on cuda:0
#   1 epochs, 24320.0 examples,9.49e-01 class acc,1.39e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 24448.0 examples,9.49e-01 class acc,1.38e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 24576.0 examples,9.49e-01 class acc,1.38e-01 bbox mae,39.8 examples/sec on cuda:0
#   1 epochs, 24704.0 examples,9.50e-01 class acc,1.38e-01 bbox mae,47.3 examples/sec on cuda:0
#   1 epochs, 24832.0 examples,9.50e-01 class acc,1.37e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 24960.0 examples,9.50e-01 class acc,1.37e-01 bbox mae,44.5 examples/sec on cuda:0
#   1 epochs, 25088.0 examples,9.50e-01 class acc,1.37e-01 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 25216.0 examples,9.50e-01 class acc,1.36e-01 bbox mae,43.3 examples/sec on cuda:0
#   1 epochs, 25344.0 examples,9.50e-01 class acc,1.36e-01 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 25472.0 examples,9.51e-01 class acc,1.35e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 25600.0 examples,9.51e-01 class acc,1.35e-01 bbox mae,38.2 examples/sec on cuda:0
#   1 epochs, 25728.0 examples,9.51e-01 class acc,1.35e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 25856.0 examples,9.51e-01 class acc,1.34e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 25984.0 examples,9.51e-01 class acc,1.34e-01 bbox mae,37.7 examples/sec on cuda:0
#   1 epochs, 26112.0 examples,9.51e-01 class acc,1.34e-01 bbox mae,46.7 examples/sec on cuda:0
#   1 epochs, 26240.0 examples,9.52e-01 class acc,1.33e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 26368.0 examples,9.52e-01 class acc,1.33e-01 bbox mae,41.4 examples/sec on cuda:0
#   1 epochs, 26496.0 examples,9.52e-01 class acc,1.33e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 26624.0 examples,9.52e-01 class acc,1.32e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 26752.0 examples,9.52e-01 class acc,1.32e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 26880.0 examples,9.52e-01 class acc,1.32e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 27008.0 examples,9.52e-01 class acc,1.31e-01 bbox mae,42.2 examples/sec on cuda:0
#   1 epochs, 27136.0 examples,9.53e-01 class acc,1.31e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 27264.0 examples,9.53e-01 class acc,1.30e-01 bbox mae,47.0 examples/sec on cuda:0
#   1 epochs, 27392.0 examples,9.53e-01 class acc,1.30e-01 bbox mae,37.8 examples/sec on cuda:0
#   1 epochs, 27520.0 examples,9.53e-01 class acc,1.30e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 27648.0 examples,9.53e-01 class acc,1.29e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 27776.0 examples,9.53e-01 class acc,1.29e-01 bbox mae,37.7 examples/sec on cuda:0
#   1 epochs, 27904.0 examples,9.54e-01 class acc,1.29e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 28032.0 examples,9.54e-01 class acc,1.28e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 28160.0 examples,9.54e-01 class acc,1.28e-01 bbox mae,41.4 examples/sec on cuda:0
#   1 epochs, 28288.0 examples,9.54e-01 class acc,1.28e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 28416.0 examples,9.54e-01 class acc,1.28e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 28544.0 examples,9.54e-01 class acc,1.27e-01 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 28672.0 examples,9.54e-01 class acc,1.27e-01 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 28800.0 examples,9.55e-01 class acc,1.27e-01 bbox mae,43.0 examples/sec on cuda:0
#   1 epochs, 28928.0 examples,9.55e-01 class acc,1.26e-01 bbox mae,44.8 examples/sec on cuda:0
#   1 epochs, 29056.0 examples,9.55e-01 class acc,1.26e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 29184.0 examples,9.55e-01 class acc,1.26e-01 bbox mae,38.0 examples/sec on cuda:0
#   1 epochs, 29312.0 examples,9.55e-01 class acc,1.26e-01 bbox mae,45.5 examples/sec on cuda:0
#   1 epochs, 29440.0 examples,9.55e-01 class acc,1.26e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 29568.0 examples,9.55e-01 class acc,1.25e-01 bbox mae,38.3 examples/sec on cuda:0
#   1 epochs, 29696.0 examples,9.56e-01 class acc,1.25e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 29824.0 examples,9.55e-01 class acc,1.25e-01 bbox mae,46.1 examples/sec on cuda:0
#   1 epochs, 29952.0 examples,9.56e-01 class acc,1.25e-01 bbox mae,43.6 examples/sec on cuda:0
#   1 epochs, 30080.0 examples,9.56e-01 class acc,1.25e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 30208.0 examples,9.56e-01 class acc,1.26e-01 bbox mae,44.3 examples/sec on cuda:0
#   1 epochs, 30336.0 examples,9.56e-01 class acc,1.27e-01 bbox mae,46.3 examples/sec on cuda:0
#   1 epochs, 30464.0 examples,9.56e-01 class acc,1.28e-01 bbox mae,47.5 examples/sec on cuda:0
#   1 epochs, 30592.0 examples,9.56e-01 class acc,1.28e-01 bbox mae,38.6 examples/sec on cuda:0
#   1 epochs, 30720.0 examples,9.56e-01 class acc,1.29e-01 bbox mae,46.8 examples/sec on cuda:0
#   1 epochs, 30848.0 examples,9.56e-01 class acc,1.29e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 30976.0 examples,9.57e-01 class acc,1.29e-01 bbox mae,37.8 examples/sec on cuda:0
#   1 epochs, 31104.0 examples,9.57e-01 class acc,1.29e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 31232.0 examples,9.57e-01 class acc,1.29e-01 bbox mae,47.5 examples/sec on cuda:0
#   1 epochs, 31360.0 examples,9.57e-01 class acc,1.29e-01 bbox mae,39.2 examples/sec on cuda:0
#   1 epochs, 31488.0 examples,9.57e-01 class acc,1.30e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 31616.0 examples,9.57e-01 class acc,1.30e-01 bbox mae,47.2 examples/sec on cuda:0
#   1 epochs, 31744.0 examples,9.57e-01 class acc,1.30e-01 bbox mae,43.3 examples/sec on cuda:0
#   1 epochs, 31872.0 examples,9.57e-01 class acc,1.30e-01 bbox mae,47.4 examples/sec on cuda:0
#   1 epochs, 32000.0 examples,9.58e-01 class acc,1.30e-01 bbox mae,45.4 examples/sec on cuda:0
#   1 epochs, 32128.0 examples,9.58e-01 class acc,1.30e-01 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 32256.0 examples,9.58e-01 class acc,1.30e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 32384.0 examples,9.58e-01 class acc,1.30e-01 bbox mae,41.4 examples/sec on cuda:0
#   1 epochs, 32512.0 examples,9.58e-01 class acc,1.29e-01 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 32640.0 examples,9.58e-01 class acc,1.29e-01 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 32768.0 examples,9.58e-01 class acc,1.29e-01 bbox mae,38.6 examples/sec on cuda:0
#   1 epochs, 32896.0 examples,9.58e-01 class acc,1.29e-01 bbox mae,46.5 examples/sec on cuda:0
#   1 epochs, 33024.0 examples,9.58e-01 class acc,1.29e-01 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 33152.0 examples,9.58e-01 class acc,1.28e-01 bbox mae,37.4 examples/sec on cuda:0
#   1 epochs, 33280.0 examples,9.58e-01 class acc,1.28e-01 bbox mae,45.7 examples/sec on cuda:0
#   1 epochs, 33354.0 examples,9.58e-01 class acc,1.28e-01 bbox mae,45.8 examples/sec on cuda:0
#  1/ 5 epoch,             class error = 0.04156609485696583, bbox mae = 0.12807702166844628
#   2 epochs, 128.0 examples,9.77e-01 class acc,6.62e-02 bbox mae,38.2 examples/sec on cuda:0
#   2 epochs, 256.0 examples,9.76e-01 class acc,6.66e-02 bbox mae,46.1 examples/sec on cuda:0
#   2 epochs, 384.0 examples,9.80e-01 class acc,6.62e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 512.0 examples,9.82e-01 class acc,6.58e-02 bbox mae,37.7 examples/sec on cuda:0
#   2 epochs, 640.0 examples,9.83e-01 class acc,6.54e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 768.0 examples,9.84e-01 class acc,6.47e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 896.0 examples,9.83e-01 class acc,6.52e-02 bbox mae,40.2 examples/sec on cuda:0
#   2 epochs, 1024.0 examples,9.84e-01 class acc,6.45e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 1152.0 examples,9.84e-01 class acc,6.39e-02 bbox mae,46.0 examples/sec on cuda:0
#   2 epochs, 1280.0 examples,9.84e-01 class acc,6.33e-02 bbox mae,43.8 examples/sec on cuda:0
#   2 epochs, 1408.0 examples,9.85e-01 class acc,6.28e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 1536.0 examples,9.84e-01 class acc,6.21e-02 bbox mae,45.4 examples/sec on cuda:0
#   2 epochs, 1664.0 examples,9.84e-01 class acc,6.14e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 1792.0 examples,9.84e-01 class acc,6.09e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 1920.0 examples,9.85e-01 class acc,6.00e-02 bbox mae,41.5 examples/sec on cuda:0
#   2 epochs, 2048.0 examples,9.85e-01 class acc,5.95e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 2176.0 examples,9.85e-01 class acc,5.89e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 2304.0 examples,9.85e-01 class acc,5.85e-02 bbox mae,38.5 examples/sec on cuda:0
#   2 epochs, 2432.0 examples,9.85e-01 class acc,5.84e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 2560.0 examples,9.85e-01 class acc,5.80e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 2688.0 examples,9.85e-01 class acc,5.79e-02 bbox mae,38.4 examples/sec on cuda:0
#   2 epochs, 2816.0 examples,9.85e-01 class acc,5.79e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 2944.0 examples,9.85e-01 class acc,5.76e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 3072.0 examples,9.85e-01 class acc,5.73e-02 bbox mae,39.6 examples/sec on cuda:0
#   2 epochs, 3200.0 examples,9.85e-01 class acc,5.73e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 3328.0 examples,9.85e-01 class acc,5.70e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 3456.0 examples,9.85e-01 class acc,5.71e-02 bbox mae,43.0 examples/sec on cuda:0
#   2 epochs, 3584.0 examples,9.85e-01 class acc,5.73e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 3712.0 examples,9.85e-01 class acc,5.74e-02 bbox mae,45.7 examples/sec on cuda:0
#   2 epochs, 3840.0 examples,9.86e-01 class acc,5.75e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 3968.0 examples,9.86e-01 class acc,5.72e-02 bbox mae,45.8 examples/sec on cuda:0
#   2 epochs, 4096.0 examples,9.86e-01 class acc,5.71e-02 bbox mae,40.7 examples/sec on cuda:0
#   2 epochs, 4224.0 examples,9.86e-01 class acc,5.69e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 4352.0 examples,9.86e-01 class acc,5.68e-02 bbox mae,46.0 examples/sec on cuda:0
#   2 epochs, 4480.0 examples,9.85e-01 class acc,5.68e-02 bbox mae,38.2 examples/sec on cuda:0
#   2 epochs, 4608.0 examples,9.85e-01 class acc,5.66e-02 bbox mae,46.2 examples/sec on cuda:0
#   2 epochs, 4736.0 examples,9.85e-01 class acc,5.65e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 4864.0 examples,9.85e-01 class acc,5.65e-02 bbox mae,38.4 examples/sec on cuda:0
#   2 epochs, 4992.0 examples,9.85e-01 class acc,5.65e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 5120.0 examples,9.85e-01 class acc,5.65e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 5248.0 examples,9.85e-01 class acc,5.62e-02 bbox mae,41.6 examples/sec on cuda:0
#   2 epochs, 5376.0 examples,9.85e-01 class acc,5.60e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 5504.0 examples,9.86e-01 class acc,5.57e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 5632.0 examples,9.86e-01 class acc,5.55e-02 bbox mae,45.2 examples/sec on cuda:0
#   2 epochs, 5760.0 examples,9.86e-01 class acc,5.53e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 5888.0 examples,9.86e-01 class acc,5.53e-02 bbox mae,44.5 examples/sec on cuda:0
#   2 epochs, 6016.0 examples,9.86e-01 class acc,5.52e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 6144.0 examples,9.86e-01 class acc,5.52e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 6272.0 examples,9.85e-01 class acc,5.54e-02 bbox mae,40.3 examples/sec on cuda:0
#   2 epochs, 6400.0 examples,9.85e-01 class acc,5.53e-02 bbox mae,46.3 examples/sec on cuda:0
#   2 epochs, 6528.0 examples,9.85e-01 class acc,5.52e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 6656.0 examples,9.85e-01 class acc,5.49e-02 bbox mae,38.1 examples/sec on cuda:0
#   2 epochs, 6784.0 examples,9.85e-01 class acc,5.48e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 6912.0 examples,9.85e-01 class acc,5.46e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 7040.0 examples,9.85e-01 class acc,5.45e-02 bbox mae,38.2 examples/sec on cuda:0
#   2 epochs, 7168.0 examples,9.85e-01 class acc,5.43e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 7296.0 examples,9.85e-01 class acc,5.41e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 7424.0 examples,9.85e-01 class acc,5.39e-02 bbox mae,41.5 examples/sec on cuda:0
#   2 epochs, 7552.0 examples,9.86e-01 class acc,5.37e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 7680.0 examples,9.86e-01 class acc,5.35e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 7808.0 examples,9.86e-01 class acc,5.33e-02 bbox mae,45.7 examples/sec on cuda:0
#   2 epochs, 7936.0 examples,9.86e-01 class acc,5.31e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 8064.0 examples,9.86e-01 class acc,5.29e-02 bbox mae,45.5 examples/sec on cuda:0
#   2 epochs, 8192.0 examples,9.86e-01 class acc,5.27e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 8320.0 examples,9.85e-01 class acc,5.26e-02 bbox mae,46.2 examples/sec on cuda:0
#   2 epochs, 8448.0 examples,9.85e-01 class acc,5.26e-02 bbox mae,40.6 examples/sec on cuda:0
#   2 epochs, 8576.0 examples,9.85e-01 class acc,5.24e-02 bbox mae,46.0 examples/sec on cuda:0
#   2 epochs, 8704.0 examples,9.85e-01 class acc,5.23e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 8832.0 examples,9.85e-01 class acc,5.23e-02 bbox mae,38.2 examples/sec on cuda:0
#   2 epochs, 8960.0 examples,9.85e-01 class acc,5.22e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 9088.0 examples,9.85e-01 class acc,5.22e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 9216.0 examples,9.85e-01 class acc,5.22e-02 bbox mae,37.0 examples/sec on cuda:0
#   2 epochs, 9344.0 examples,9.85e-01 class acc,5.21e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 9472.0 examples,9.85e-01 class acc,5.20e-02 bbox mae,47.7 examples/sec on cuda:0
#   2 epochs, 9600.0 examples,9.86e-01 class acc,5.19e-02 bbox mae,41.3 examples/sec on cuda:0
#   2 epochs, 9728.0 examples,9.86e-01 class acc,5.18e-02 bbox mae,47.8 examples/sec on cuda:0
#   2 epochs, 9856.0 examples,9.86e-01 class acc,5.17e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 9984.0 examples,9.86e-01 class acc,5.17e-02 bbox mae,43.8 examples/sec on cuda:0
#   2 epochs, 10112.0 examples,9.86e-01 class acc,5.16e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 10240.0 examples,9.86e-01 class acc,5.15e-02 bbox mae,45.3 examples/sec on cuda:0
#   2 epochs, 10368.0 examples,9.86e-01 class acc,5.15e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 10496.0 examples,9.86e-01 class acc,5.14e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 10624.0 examples,9.86e-01 class acc,5.14e-02 bbox mae,40.9 examples/sec on cuda:0
#   2 epochs, 10752.0 examples,9.86e-01 class acc,5.13e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 10880.0 examples,9.86e-01 class acc,5.13e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 11008.0 examples,9.86e-01 class acc,5.12e-02 bbox mae,37.8 examples/sec on cuda:0
#   2 epochs, 11136.0 examples,9.86e-01 class acc,5.12e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 11264.0 examples,9.86e-01 class acc,5.11e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 11392.0 examples,9.86e-01 class acc,5.11e-02 bbox mae,38.1 examples/sec on cuda:0
#   2 epochs, 11520.0 examples,9.86e-01 class acc,5.10e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 11648.0 examples,9.86e-01 class acc,5.10e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 11776.0 examples,9.86e-01 class acc,5.09e-02 bbox mae,40.2 examples/sec on cuda:0
#   2 epochs, 11904.0 examples,9.86e-01 class acc,5.09e-02 bbox mae,47.8 examples/sec on cuda:0
#   2 epochs, 12032.0 examples,9.86e-01 class acc,5.08e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 12160.0 examples,9.86e-01 class acc,5.07e-02 bbox mae,43.2 examples/sec on cuda:0
#   2 epochs, 12288.0 examples,9.86e-01 class acc,5.06e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 12416.0 examples,9.86e-01 class acc,5.06e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 12544.0 examples,9.86e-01 class acc,5.05e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 12672.0 examples,9.86e-01 class acc,5.05e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 12800.0 examples,9.86e-01 class acc,5.04e-02 bbox mae,42.8 examples/sec on cuda:0
#   2 epochs, 12928.0 examples,9.86e-01 class acc,5.03e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 13056.0 examples,9.86e-01 class acc,5.02e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 13184.0 examples,9.86e-01 class acc,5.02e-02 bbox mae,37.6 examples/sec on cuda:0
#   2 epochs, 13312.0 examples,9.86e-01 class acc,5.01e-02 bbox mae,46.0 examples/sec on cuda:0
#   2 epochs, 13440.0 examples,9.86e-01 class acc,5.00e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 13568.0 examples,9.86e-01 class acc,5.00e-02 bbox mae,38.1 examples/sec on cuda:0
#   2 epochs, 13696.0 examples,9.86e-01 class acc,4.99e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 13824.0 examples,9.86e-01 class acc,4.98e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 13952.0 examples,9.86e-01 class acc,4.97e-02 bbox mae,39.9 examples/sec on cuda:0
#   2 epochs, 14080.0 examples,9.86e-01 class acc,4.96e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 14208.0 examples,9.86e-01 class acc,4.95e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 14336.0 examples,9.86e-01 class acc,4.94e-02 bbox mae,43.2 examples/sec on cuda:0
#   2 epochs, 14464.0 examples,9.86e-01 class acc,4.94e-02 bbox mae,46.1 examples/sec on cuda:0
#   2 epochs, 14592.0 examples,9.86e-01 class acc,4.93e-02 bbox mae,46.2 examples/sec on cuda:0
#   2 epochs, 14720.0 examples,9.86e-01 class acc,4.92e-02 bbox mae,46.3 examples/sec on cuda:0
#   2 epochs, 14848.0 examples,9.86e-01 class acc,4.91e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 14976.0 examples,9.86e-01 class acc,4.91e-02 bbox mae,42.5 examples/sec on cuda:0
#   2 epochs, 15104.0 examples,9.87e-01 class acc,4.90e-02 bbox mae,46.3 examples/sec on cuda:0
#   2 epochs, 15232.0 examples,9.87e-01 class acc,4.89e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 15360.0 examples,9.87e-01 class acc,4.88e-02 bbox mae,37.8 examples/sec on cuda:0
#   2 epochs, 15488.0 examples,9.87e-01 class acc,4.87e-02 bbox mae,45.9 examples/sec on cuda:0
#   2 epochs, 15616.0 examples,9.87e-01 class acc,4.87e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 15744.0 examples,9.87e-01 class acc,4.86e-02 bbox mae,37.8 examples/sec on cuda:0
#   2 epochs, 15872.0 examples,9.87e-01 class acc,4.85e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 16000.0 examples,9.87e-01 class acc,4.85e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 16128.0 examples,9.87e-01 class acc,4.84e-02 bbox mae,40.1 examples/sec on cuda:0
#   2 epochs, 16256.0 examples,9.87e-01 class acc,4.83e-02 bbox mae,47.7 examples/sec on cuda:0
#   2 epochs, 16384.0 examples,9.87e-01 class acc,4.83e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 16512.0 examples,9.87e-01 class acc,4.82e-02 bbox mae,42.5 examples/sec on cuda:0
#   2 epochs, 16640.0 examples,9.87e-01 class acc,4.81e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 16768.0 examples,9.87e-01 class acc,4.81e-02 bbox mae,47.4 examples/sec on cuda:0
#   2 epochs, 16896.0 examples,9.87e-01 class acc,4.80e-02 bbox mae,45.8 examples/sec on cuda:0
#   2 epochs, 17024.0 examples,9.87e-01 class acc,4.80e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 17152.0 examples,9.87e-01 class acc,4.79e-02 bbox mae,43.5 examples/sec on cuda:0
#   2 epochs, 17280.0 examples,9.87e-01 class acc,4.79e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 17408.0 examples,9.87e-01 class acc,4.78e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 17536.0 examples,9.87e-01 class acc,4.77e-02 bbox mae,38.1 examples/sec on cuda:0
#   2 epochs, 17664.0 examples,9.87e-01 class acc,4.77e-02 bbox mae,46.3 examples/sec on cuda:0
#   2 epochs, 17792.0 examples,9.87e-01 class acc,4.76e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 17920.0 examples,9.87e-01 class acc,4.76e-02 bbox mae,38.6 examples/sec on cuda:0
#   2 epochs, 18048.0 examples,9.87e-01 class acc,4.75e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 18176.0 examples,9.87e-01 class acc,4.74e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 18304.0 examples,9.87e-01 class acc,4.74e-02 bbox mae,39.2 examples/sec on cuda:0
#   2 epochs, 18432.0 examples,9.87e-01 class acc,4.73e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 18560.0 examples,9.87e-01 class acc,4.72e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 18688.0 examples,9.87e-01 class acc,4.72e-02 bbox mae,42.4 examples/sec on cuda:0
#   2 epochs, 18816.0 examples,9.87e-01 class acc,4.71e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 18944.0 examples,9.87e-01 class acc,4.71e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 19072.0 examples,9.87e-01 class acc,4.70e-02 bbox mae,45.6 examples/sec on cuda:0
#   2 epochs, 19200.0 examples,9.87e-01 class acc,4.69e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 19328.0 examples,9.87e-01 class acc,4.69e-02 bbox mae,42.9 examples/sec on cuda:0
#   2 epochs, 19456.0 examples,9.87e-01 class acc,4.68e-02 bbox mae,46.2 examples/sec on cuda:0
#   2 epochs, 19584.0 examples,9.87e-01 class acc,4.68e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 19712.0 examples,9.87e-01 class acc,4.67e-02 bbox mae,38.9 examples/sec on cuda:0
#   2 epochs, 19840.0 examples,9.87e-01 class acc,4.67e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 19968.0 examples,9.87e-01 class acc,4.66e-02 bbox mae,47.7 examples/sec on cuda:0
#   2 epochs, 20096.0 examples,9.87e-01 class acc,4.65e-02 bbox mae,37.9 examples/sec on cuda:0
#   2 epochs, 20224.0 examples,9.87e-01 class acc,4.65e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 20352.0 examples,9.87e-01 class acc,4.64e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 20480.0 examples,9.87e-01 class acc,4.64e-02 bbox mae,38.3 examples/sec on cuda:0
#   2 epochs, 20608.0 examples,9.87e-01 class acc,4.63e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 20736.0 examples,9.87e-01 class acc,4.63e-02 bbox mae,48.4 examples/sec on cuda:0
#   2 epochs, 20864.0 examples,9.87e-01 class acc,4.62e-02 bbox mae,41.1 examples/sec on cuda:0
#   2 epochs, 20992.0 examples,9.87e-01 class acc,4.62e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 21120.0 examples,9.87e-01 class acc,4.61e-02 bbox mae,48.1 examples/sec on cuda:0
#   2 epochs, 21248.0 examples,9.87e-01 class acc,4.60e-02 bbox mae,43.5 examples/sec on cuda:0
#   2 epochs, 21376.0 examples,9.87e-01 class acc,4.60e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 21504.0 examples,9.87e-01 class acc,4.59e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 21632.0 examples,9.87e-01 class acc,4.58e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 21760.0 examples,9.87e-01 class acc,4.58e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 21888.0 examples,9.87e-01 class acc,4.57e-02 bbox mae,42.7 examples/sec on cuda:0
#   2 epochs, 22016.0 examples,9.87e-01 class acc,4.57e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 22144.0 examples,9.87e-01 class acc,4.56e-02 bbox mae,47.8 examples/sec on cuda:0
#   2 epochs, 22272.0 examples,9.87e-01 class acc,4.56e-02 bbox mae,39.4 examples/sec on cuda:0
#   2 epochs, 22400.0 examples,9.88e-01 class acc,4.55e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 22528.0 examples,9.88e-01 class acc,4.55e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 22656.0 examples,9.88e-01 class acc,4.54e-02 bbox mae,38.7 examples/sec on cuda:0
#   2 epochs, 22784.0 examples,9.88e-01 class acc,4.54e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 22912.0 examples,9.88e-01 class acc,4.53e-02 bbox mae,47.5 examples/sec on cuda:0
#   2 epochs, 23040.0 examples,9.88e-01 class acc,4.52e-02 bbox mae,38.0 examples/sec on cuda:0
#   2 epochs, 23168.0 examples,9.88e-01 class acc,4.52e-02 bbox mae,47.9 examples/sec on cuda:0
#   2 epochs, 23296.0 examples,9.88e-01 class acc,4.52e-02 bbox mae,48.7 examples/sec on cuda:0
#   2 epochs, 23424.0 examples,9.88e-01 class acc,4.51e-02 bbox mae,40.9 examples/sec on cuda:0
#   2 epochs, 23552.0 examples,9.88e-01 class acc,4.51e-02 bbox mae,47.9 examples/sec on cuda:0
#   2 epochs, 23680.0 examples,9.88e-01 class acc,4.50e-02 bbox mae,48.2 examples/sec on cuda:0
#   2 epochs, 23808.0 examples,9.88e-01 class acc,4.49e-02 bbox mae,42.4 examples/sec on cuda:0
#   2 epochs, 23936.0 examples,9.88e-01 class acc,4.49e-02 bbox mae,48.1 examples/sec on cuda:0
#   2 epochs, 24064.0 examples,9.88e-01 class acc,4.48e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 24192.0 examples,9.88e-01 class acc,4.48e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 24320.0 examples,9.88e-01 class acc,4.47e-02 bbox mae,48.0 examples/sec on cuda:0
#   2 epochs, 24448.0 examples,9.88e-01 class acc,4.47e-02 bbox mae,44.5 examples/sec on cuda:0
#   2 epochs, 24576.0 examples,9.88e-01 class acc,4.46e-02 bbox mae,47.8 examples/sec on cuda:0
#   2 epochs, 24704.0 examples,9.88e-01 class acc,4.46e-02 bbox mae,48.3 examples/sec on cuda:0
#   2 epochs, 24832.0 examples,9.88e-01 class acc,4.45e-02 bbox mae,41.1 examples/sec on cuda:0
#   2 epochs, 24960.0 examples,9.88e-01 class acc,4.45e-02 bbox mae,47.9 examples/sec on cuda:0
#   2 epochs, 25088.0 examples,9.88e-01 class acc,4.44e-02 bbox mae,47.9 examples/sec on cuda:0
#   2 epochs, 25216.0 examples,9.88e-01 class acc,4.44e-02 bbox mae,38.4 examples/sec on cuda:0
#   2 epochs, 25344.0 examples,9.88e-01 class acc,4.43e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 25472.0 examples,9.88e-01 class acc,4.43e-02 bbox mae,47.3 examples/sec on cuda:0
#   2 epochs, 25600.0 examples,9.88e-01 class acc,4.42e-02 bbox mae,38.6 examples/sec on cuda:0
#   2 epochs, 25728.0 examples,9.88e-01 class acc,4.42e-02 bbox mae,47.8 examples/sec on cuda:0
#   2 epochs, 25856.0 examples,9.88e-01 class acc,4.41e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 25984.0 examples,9.88e-01 class acc,4.40e-02 bbox mae,40.1 examples/sec on cuda:0
#   2 epochs, 26112.0 examples,9.88e-01 class acc,4.40e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 26240.0 examples,9.88e-01 class acc,4.39e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 26368.0 examples,9.88e-01 class acc,4.39e-02 bbox mae,43.2 examples/sec on cuda:0
#   2 epochs, 26496.0 examples,9.88e-01 class acc,4.38e-02 bbox mae,46.7 examples/sec on cuda:0
#   2 epochs, 26624.0 examples,9.88e-01 class acc,4.38e-02 bbox mae,46.0 examples/sec on cuda:0
#   2 epochs, 26752.0 examples,9.88e-01 class acc,4.37e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 26880.0 examples,9.88e-01 class acc,4.37e-02 bbox mae,47.1 examples/sec on cuda:0
#   2 epochs, 27008.0 examples,9.88e-01 class acc,4.36e-02 bbox mae,42.7 examples/sec on cuda:0
#   2 epochs, 27136.0 examples,9.88e-01 class acc,4.36e-02 bbox mae,46.4 examples/sec on cuda:0
#   2 epochs, 27264.0 examples,9.88e-01 class acc,4.35e-02 bbox mae,46.8 examples/sec on cuda:0
#   2 epochs, 27392.0 examples,9.88e-01 class acc,4.35e-02 bbox mae,38.6 examples/sec on cuda:0
#   2 epochs, 27520.0 examples,9.88e-01 class acc,4.34e-02 bbox mae,46.3 examples/sec on cuda:0
#   2 epochs, 27648.0 examples,9.88e-01 class acc,4.34e-02 bbox mae,47.6 examples/sec on cuda:0
#   2 epochs, 27776.0 examples,9.88e-01 class acc,4.34e-02 bbox mae,38.6 examples/sec on cuda:0
#   2 epochs, 27904.0 examples,9.88e-01 class acc,4.34e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 28032.0 examples,9.88e-01 class acc,4.34e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 28160.0 examples,9.88e-01 class acc,4.34e-02 bbox mae,39.2 examples/sec on cuda:0
#   2 epochs, 28288.0 examples,9.88e-01 class acc,4.33e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 28416.0 examples,9.88e-01 class acc,4.33e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 28544.0 examples,9.88e-01 class acc,4.33e-02 bbox mae,43.0 examples/sec on cuda:0
#   2 epochs, 28672.0 examples,9.88e-01 class acc,4.33e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 28800.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,45.8 examples/sec on cuda:0
#   2 epochs, 28928.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 29056.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 29184.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,41.2 examples/sec on cuda:0
#   2 epochs, 29312.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,46.1 examples/sec on cuda:0
#   2 epochs, 29440.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,47.2 examples/sec on cuda:0
#   2 epochs, 29568.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,37.8 examples/sec on cuda:0
#   2 epochs, 29696.0 examples,9.88e-01 class acc,4.33e-02 bbox mae,46.2 examples/sec on cuda:0
#   2 epochs, 29824.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,46.3 examples/sec on cuda:0
#   2 epochs, 29952.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,37.4 examples/sec on cuda:0
#   2 epochs, 30080.0 examples,9.88e-01 class acc,4.32e-02 bbox mae,46.1 examples/sec on cuda:0
#   2 epochs, 30208.0 examples,9.88e-01 class acc,4.31e-02 bbox mae,47.0 examples/sec on cuda:0
#   2 epochs, 30336.0 examples,9.88e-01 class acc,4.31e-02 bbox mae,40.6 examples/sec on cuda:0
#   2 epochs, 30464.0 examples,9.88e-01 class acc,4.30e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 30592.0 examples,9.88e-01 class acc,4.30e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 30720.0 examples,9.88e-01 class acc,4.29e-02 bbox mae,45.2 examples/sec on cuda:0
#   2 epochs, 30848.0 examples,9.88e-01 class acc,4.29e-02 bbox mae,46.5 examples/sec on cuda:0
#   2 epochs, 30976.0 examples,9.88e-01 class acc,4.28e-02 bbox mae,43.1 examples/sec on cuda:0
#   2 epochs, 31104.0 examples,9.88e-01 class acc,4.28e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 31232.0 examples,9.88e-01 class acc,4.27e-02 bbox mae,46.2 examples/sec on cuda:0
#   2 epochs, 31360.0 examples,9.88e-01 class acc,4.26e-02 bbox mae,37.5 examples/sec on cuda:0
#   2 epochs, 31488.0 examples,9.88e-01 class acc,4.26e-02 bbox mae,46.1 examples/sec on cuda:0
#   2 epochs, 31616.0 examples,9.88e-01 class acc,4.25e-02 bbox mae,46.6 examples/sec on cuda:0
#   2 epochs, 31744.0 examples,9.88e-01 class acc,4.24e-02 bbox mae,37.5 examples/sec on cuda:0
#   2 epochs, 31872.0 examples,9.88e-01 class acc,4.24e-02 bbox mae,46.9 examples/sec on cuda:0
#   2 epochs, 32000.0 examples,9.87e-01 class acc,4.24e-02 bbox mae,46.3 examples/sec on cuda:0
# ...
#   5 epochs, 12032.0 examples,9.89e-01 class acc,2.43e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 12160.0 examples,9.89e-01 class acc,2.43e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 12288.0 examples,9.89e-01 class acc,2.42e-02 bbox mae,44.3 examples/sec on cuda:0
#   5 epochs, 12416.0 examples,9.89e-01 class acc,2.42e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 12544.0 examples,9.89e-01 class acc,2.41e-02 bbox mae,46.4 examples/sec on cuda:0
#   5 epochs, 12672.0 examples,9.89e-01 class acc,2.41e-02 bbox mae,46.7 examples/sec on cuda:0
#   5 epochs, 12800.0 examples,9.89e-01 class acc,2.40e-02 bbox mae,47.4 examples/sec on cuda:0
#   5 epochs, 12928.0 examples,9.89e-01 class acc,2.40e-02 bbox mae,42.9 examples/sec on cuda:0
#   5 epochs, 13056.0 examples,9.89e-01 class acc,2.39e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 13184.0 examples,9.89e-01 class acc,2.39e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 13312.0 examples,9.89e-01 class acc,2.39e-02 bbox mae,39.4 examples/sec on cuda:0
#   5 epochs, 13440.0 examples,9.89e-01 class acc,2.38e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 13568.0 examples,9.89e-01 class acc,2.38e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 13696.0 examples,9.89e-01 class acc,2.38e-02 bbox mae,38.6 examples/sec on cuda:0
#   5 epochs, 13824.0 examples,9.89e-01 class acc,2.37e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 13952.0 examples,9.89e-01 class acc,2.37e-02 bbox mae,47.9 examples/sec on cuda:0
#   5 epochs, 14080.0 examples,9.89e-01 class acc,2.37e-02 bbox mae,37.8 examples/sec on cuda:0
#   5 epochs, 14208.0 examples,9.89e-01 class acc,2.36e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 14336.0 examples,9.89e-01 class acc,2.36e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 14464.0 examples,9.89e-01 class acc,2.35e-02 bbox mae,39.9 examples/sec on cuda:0
#   5 epochs, 14592.0 examples,9.89e-01 class acc,2.35e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 14720.0 examples,9.89e-01 class acc,2.34e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 14848.0 examples,9.89e-01 class acc,2.34e-02 bbox mae,42.6 examples/sec on cuda:0
#   5 epochs, 14976.0 examples,9.89e-01 class acc,2.34e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 15104.0 examples,9.89e-01 class acc,2.33e-02 bbox mae,48.1 examples/sec on cuda:0
#   5 epochs, 15232.0 examples,9.89e-01 class acc,2.33e-02 bbox mae,45.6 examples/sec on cuda:0
#   5 epochs, 15360.0 examples,9.89e-01 class acc,2.33e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 15488.0 examples,9.89e-01 class acc,2.32e-02 bbox mae,45.4 examples/sec on cuda:0
#   5 epochs, 15616.0 examples,9.89e-01 class acc,2.32e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 15744.0 examples,9.89e-01 class acc,2.31e-02 bbox mae,47.9 examples/sec on cuda:0
#   5 epochs, 15872.0 examples,9.89e-01 class acc,2.31e-02 bbox mae,42.0 examples/sec on cuda:0
#   5 epochs, 16000.0 examples,9.89e-01 class acc,2.31e-02 bbox mae,46.9 examples/sec on cuda:0
#   5 epochs, 16128.0 examples,9.89e-01 class acc,2.30e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 16256.0 examples,9.89e-01 class acc,2.30e-02 bbox mae,38.8 examples/sec on cuda:0
#   5 epochs, 16384.0 examples,9.89e-01 class acc,2.30e-02 bbox mae,46.3 examples/sec on cuda:0
#   5 epochs, 16512.0 examples,9.89e-01 class acc,2.29e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 16640.0 examples,9.89e-01 class acc,2.29e-02 bbox mae,39.0 examples/sec on cuda:0
#   5 epochs, 16768.0 examples,9.89e-01 class acc,2.29e-02 bbox mae,46.9 examples/sec on cuda:0
#   5 epochs, 16896.0 examples,9.89e-01 class acc,2.28e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 17024.0 examples,9.89e-01 class acc,2.28e-02 bbox mae,37.7 examples/sec on cuda:0
#   5 epochs, 17152.0 examples,9.89e-01 class acc,2.28e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 17280.0 examples,9.89e-01 class acc,2.27e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 17408.0 examples,9.89e-01 class acc,2.27e-02 bbox mae,40.3 examples/sec on cuda:0
#   5 epochs, 17536.0 examples,9.89e-01 class acc,2.27e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 17664.0 examples,9.88e-01 class acc,2.29e-02 bbox mae,48.1 examples/sec on cuda:0
#   5 epochs, 17792.0 examples,9.88e-01 class acc,2.35e-02 bbox mae,42.7 examples/sec on cuda:0
#   5 epochs, 17920.0 examples,9.88e-01 class acc,2.43e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 18048.0 examples,9.88e-01 class acc,2.52e-02 bbox mae,48.2 examples/sec on cuda:0
#   5 epochs, 18176.0 examples,9.88e-01 class acc,2.60e-02 bbox mae,45.4 examples/sec on cuda:0
#   5 epochs, 18304.0 examples,9.88e-01 class acc,2.67e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 18432.0 examples,9.88e-01 class acc,2.76e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 18560.0 examples,9.88e-01 class acc,2.85e-02 bbox mae,46.4 examples/sec on cuda:0
#   5 epochs, 18688.0 examples,9.88e-01 class acc,2.96e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 18816.0 examples,9.88e-01 class acc,3.06e-02 bbox mae,43.2 examples/sec on cuda:0
#   5 epochs, 18944.0 examples,9.87e-01 class acc,3.13e-02 bbox mae,46.8 examples/sec on cuda:0
#   5 epochs, 19072.0 examples,9.88e-01 class acc,3.20e-02 bbox mae,47.9 examples/sec on cuda:0
#   5 epochs, 19200.0 examples,9.88e-01 class acc,3.28e-02 bbox mae,40.5 examples/sec on cuda:0
#   5 epochs, 19328.0 examples,9.88e-01 class acc,3.36e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 19456.0 examples,9.88e-01 class acc,3.42e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 19584.0 examples,9.88e-01 class acc,3.48e-02 bbox mae,39.1 examples/sec on cuda:0
#   5 epochs, 19712.0 examples,9.88e-01 class acc,3.52e-02 bbox mae,47.4 examples/sec on cuda:0
#   5 epochs, 19840.0 examples,9.88e-01 class acc,3.55e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 19968.0 examples,9.88e-01 class acc,3.60e-02 bbox mae,39.2 examples/sec on cuda:0
#   5 epochs, 20096.0 examples,9.88e-01 class acc,3.62e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 20224.0 examples,9.88e-01 class acc,3.64e-02 bbox mae,46.9 examples/sec on cuda:0
#   5 epochs, 20352.0 examples,9.88e-01 class acc,3.67e-02 bbox mae,38.3 examples/sec on cuda:0
#   5 epochs, 20480.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 20608.0 examples,9.87e-01 class acc,3.73e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 20736.0 examples,9.87e-01 class acc,3.77e-02 bbox mae,41.6 examples/sec on cuda:0
#   5 epochs, 20864.0 examples,9.87e-01 class acc,3.84e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 20992.0 examples,9.87e-01 class acc,3.89e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 21120.0 examples,9.87e-01 class acc,3.93e-02 bbox mae,43.6 examples/sec on cuda:0
#   5 epochs, 21248.0 examples,9.87e-01 class acc,3.97e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 21376.0 examples,9.87e-01 class acc,4.00e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 21504.0 examples,9.87e-01 class acc,4.02e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 21632.0 examples,9.87e-01 class acc,4.05e-02 bbox mae,48.1 examples/sec on cuda:0
#   5 epochs, 21760.0 examples,9.87e-01 class acc,4.06e-02 bbox mae,44.0 examples/sec on cuda:0
#   5 epochs, 21888.0 examples,9.87e-01 class acc,4.07e-02 bbox mae,46.7 examples/sec on cuda:0
#   5 epochs, 22016.0 examples,9.87e-01 class acc,4.07e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 22144.0 examples,9.87e-01 class acc,4.08e-02 bbox mae,40.2 examples/sec on cuda:0
#   5 epochs, 22272.0 examples,9.87e-01 class acc,4.08e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 22400.0 examples,9.87e-01 class acc,4.08e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 22528.0 examples,9.87e-01 class acc,4.09e-02 bbox mae,39.1 examples/sec on cuda:0
#   5 epochs, 22656.0 examples,9.87e-01 class acc,4.10e-02 bbox mae,46.4 examples/sec on cuda:0
#   5 epochs, 22784.0 examples,9.87e-01 class acc,4.10e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 22912.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,37.9 examples/sec on cuda:0
#   5 epochs, 23040.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 23168.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 23296.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,40.2 examples/sec on cuda:0
#   5 epochs, 23424.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 23552.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 23680.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,43.0 examples/sec on cuda:0
#   5 epochs, 23808.0 examples,9.87e-01 class acc,4.11e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 23936.0 examples,9.87e-01 class acc,4.10e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 24064.0 examples,9.87e-01 class acc,4.10e-02 bbox mae,45.8 examples/sec on cuda:0
#   5 epochs, 24192.0 examples,9.87e-01 class acc,4.09e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 24320.0 examples,9.87e-01 class acc,4.09e-02 bbox mae,45.4 examples/sec on cuda:0
#   5 epochs, 24448.0 examples,9.87e-01 class acc,4.08e-02 bbox mae,46.7 examples/sec on cuda:0
#   5 epochs, 24576.0 examples,9.87e-01 class acc,4.08e-02 bbox mae,47.4 examples/sec on cuda:0
#   5 epochs, 24704.0 examples,9.87e-01 class acc,4.07e-02 bbox mae,42.1 examples/sec on cuda:0
#   5 epochs, 24832.0 examples,9.87e-01 class acc,4.06e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 24960.0 examples,9.87e-01 class acc,4.06e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 25088.0 examples,9.87e-01 class acc,4.05e-02 bbox mae,39.4 examples/sec on cuda:0
#   5 epochs, 25216.0 examples,9.87e-01 class acc,4.04e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 25344.0 examples,9.87e-01 class acc,4.04e-02 bbox mae,47.4 examples/sec on cuda:0
#   5 epochs, 25472.0 examples,9.87e-01 class acc,4.03e-02 bbox mae,38.7 examples/sec on cuda:0
#   5 epochs, 25600.0 examples,9.87e-01 class acc,4.02e-02 bbox mae,47.0 examples/sec on cuda:0
#   5 epochs, 25728.0 examples,9.87e-01 class acc,4.02e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 25856.0 examples,9.87e-01 class acc,4.01e-02 bbox mae,38.0 examples/sec on cuda:0
#   5 epochs, 25984.0 examples,9.87e-01 class acc,4.01e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 26112.0 examples,9.87e-01 class acc,4.01e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 26240.0 examples,9.87e-01 class acc,4.00e-02 bbox mae,40.4 examples/sec on cuda:0
#   5 epochs, 26368.0 examples,9.87e-01 class acc,4.00e-02 bbox mae,47.9 examples/sec on cuda:0
#   5 epochs, 26496.0 examples,9.87e-01 class acc,3.99e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 26624.0 examples,9.87e-01 class acc,3.99e-02 bbox mae,42.8 examples/sec on cuda:0
#   5 epochs, 26752.0 examples,9.87e-01 class acc,3.98e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 26880.0 examples,9.87e-01 class acc,3.98e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 27008.0 examples,9.87e-01 class acc,3.97e-02 bbox mae,46.3 examples/sec on cuda:0
#   5 epochs, 27136.0 examples,9.87e-01 class acc,3.97e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 27264.0 examples,9.87e-01 class acc,3.96e-02 bbox mae,45.6 examples/sec on cuda:0
#   5 epochs, 27392.0 examples,9.87e-01 class acc,3.96e-02 bbox mae,46.0 examples/sec on cuda:0
#   5 epochs, 27520.0 examples,9.87e-01 class acc,3.95e-02 bbox mae,47.9 examples/sec on cuda:0
#   5 epochs, 27648.0 examples,9.87e-01 class acc,3.94e-02 bbox mae,42.3 examples/sec on cuda:0
#   5 epochs, 27776.0 examples,9.87e-01 class acc,3.94e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 27904.0 examples,9.87e-01 class acc,3.93e-02 bbox mae,46.8 examples/sec on cuda:0
#   5 epochs, 28032.0 examples,9.87e-01 class acc,3.92e-02 bbox mae,38.9 examples/sec on cuda:0
#   5 epochs, 28160.0 examples,9.87e-01 class acc,3.91e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 28288.0 examples,9.87e-01 class acc,3.91e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 28416.0 examples,9.87e-01 class acc,3.90e-02 bbox mae,39.0 examples/sec on cuda:0
#   5 epochs, 28544.0 examples,9.87e-01 class acc,3.89e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 28672.0 examples,9.87e-01 class acc,3.88e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 28800.0 examples,9.87e-01 class acc,3.88e-02 bbox mae,38.6 examples/sec on cuda:0
#   5 epochs, 28928.0 examples,9.87e-01 class acc,3.87e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 29056.0 examples,9.87e-01 class acc,3.86e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 29184.0 examples,9.87e-01 class acc,3.86e-02 bbox mae,40.9 examples/sec on cuda:0
#   5 epochs, 29312.0 examples,9.87e-01 class acc,3.85e-02 bbox mae,46.5 examples/sec on cuda:0
#   5 epochs, 29440.0 examples,9.87e-01 class acc,3.84e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 29568.0 examples,9.87e-01 class acc,3.83e-02 bbox mae,44.2 examples/sec on cuda:0
#   5 epochs, 29696.0 examples,9.87e-01 class acc,3.83e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 29824.0 examples,9.87e-01 class acc,3.82e-02 bbox mae,46.4 examples/sec on cuda:0
#   5 epochs, 29952.0 examples,9.87e-01 class acc,3.81e-02 bbox mae,46.6 examples/sec on cuda:0
#   5 epochs, 30080.0 examples,9.87e-01 class acc,3.81e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 30208.0 examples,9.87e-01 class acc,3.80e-02 bbox mae,42.3 examples/sec on cuda:0
#   5 epochs, 30336.0 examples,9.87e-01 class acc,3.79e-02 bbox mae,46.5 examples/sec on cuda:0
#   5 epochs, 30464.0 examples,9.87e-01 class acc,3.78e-02 bbox mae,47.5 examples/sec on cuda:0
#   5 epochs, 30592.0 examples,9.87e-01 class acc,3.78e-02 bbox mae,39.4 examples/sec on cuda:0
#   5 epochs, 30720.0 examples,9.87e-01 class acc,3.77e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 30848.0 examples,9.87e-01 class acc,3.77e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 30976.0 examples,9.87e-01 class acc,3.76e-02 bbox mae,38.0 examples/sec on cuda:0
#   5 epochs, 31104.0 examples,9.87e-01 class acc,3.75e-02 bbox mae,47.4 examples/sec on cuda:0
#   5 epochs, 31232.0 examples,9.87e-01 class acc,3.75e-02 bbox mae,47.9 examples/sec on cuda:0
#   5 epochs, 31360.0 examples,9.87e-01 class acc,3.74e-02 bbox mae,38.4 examples/sec on cuda:0
#   5 epochs, 31488.0 examples,9.87e-01 class acc,3.73e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 31616.0 examples,9.87e-01 class acc,3.73e-02 bbox mae,47.7 examples/sec on cuda:0
#   5 epochs, 31744.0 examples,9.87e-01 class acc,3.72e-02 bbox mae,40.6 examples/sec on cuda:0
#   5 epochs, 31872.0 examples,9.87e-01 class acc,3.71e-02 bbox mae,48.0 examples/sec on cuda:0
#   5 epochs, 32000.0 examples,9.87e-01 class acc,3.71e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 32128.0 examples,9.87e-01 class acc,3.71e-02 bbox mae,43.5 examples/sec on cuda:0
#   5 epochs, 32256.0 examples,9.87e-01 class acc,3.71e-02 bbox mae,47.8 examples/sec on cuda:0
#   5 epochs, 32384.0 examples,9.87e-01 class acc,3.71e-02 bbox mae,47.6 examples/sec on cuda:0
#   5 epochs, 32512.0 examples,9.87e-01 class acc,3.71e-02 bbox mae,45.9 examples/sec on cuda:0
#   5 epochs, 32640.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,47.1 examples/sec on cuda:0
#   5 epochs, 32768.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,44.5 examples/sec on cuda:0
#   5 epochs, 32896.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,47.3 examples/sec on cuda:0
#   5 epochs, 33024.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,46.9 examples/sec on cuda:0
#   5 epochs, 33152.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,41.9 examples/sec on cuda:0
#   5 epochs, 33280.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,47.2 examples/sec on cuda:0
#   5 epochs, 33354.0 examples,9.87e-01 class acc,3.70e-02 bbox mae,47.2 examples/sec on cuda:0
#  5/ 5 epoch,             class error = 0.012842743144411806, bbox mae = 0.03703343000865169
# class err 1.28e-02, bbox mae 3.70e-02
# 21261.4 examples/sec on cuda:0

# %%
# 将学习率手动调小十倍继续训练
optimizer.param_groups[0]['lr'] *= 0.1

# %%
train(
    net = net,
    train_dataloader = train_dataloader,
    optimizer = optimizer,
    num_epochs = num_epochs,
    device = device
)
# Out:
#   1 epochs, 128.0 examples,9.91e-01 class acc,4.13e-02 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 256.0 examples,9.91e-01 class acc,4.05e-02 bbox mae,46.4 examples/sec on cuda:0
#   1 epochs, 384.0 examples,9.91e-01 class acc,4.08e-02 bbox mae,47.6 examples/sec on cuda:0
#   1 epochs, 512.0 examples,9.91e-01 class acc,4.03e-02 bbox mae,45.6 examples/sec on cuda:0
#   1 epochs, 640.0 examples,9.91e-01 class acc,3.99e-02 bbox mae,46.6 examples/sec on cuda:0
#   1 epochs, 768.0 examples,9.91e-01 class acc,3.94e-02 bbox mae,47.7 examples/sec on cuda:0
#   1 epochs, 896.0 examples,9.91e-01 class acc,3.84e-02 bbox mae,40.0 examples/sec on cuda:0
#   1 epochs, 1024.0 examples,9.91e-01 class acc,3.80e-02 bbox mae,46.2 examples/sec on cuda:0
#   1 epochs, 1152.0 examples,9.91e-01 class acc,3.76e-02 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 1280.0 examples,9.91e-01 class acc,3.72e-02 bbox mae,38.7 examples/sec on cuda:0
#   1 epochs, 1408.0 examples,9.91e-01 class acc,3.70e-02 bbox mae,47.1 examples/sec on cuda:0
#   1 epochs, 1536.0 examples,9.91e-01 class acc,3.66e-02 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 1664.0 examples,9.91e-01 class acc,3.62e-02 bbox mae,39.0 examples/sec on cuda:0
#   1 epochs, 1792.0 examples,9.91e-01 class acc,3.58e-02 bbox mae,47.5 examples/sec on cuda:0
#   1 epochs, 1920.0 examples,9.91e-01 class acc,3.56e-02 bbox mae,47.5 examples/sec on cuda:0
#   1 epochs, 2048.0 examples,9.91e-01 class acc,3.52e-02 bbox mae,38.8 examples/sec on cuda:0
#   1 epochs, 2176.0 examples,9.91e-01 class acc,3.49e-02 bbox mae,47.6 examples/sec on cuda:0
#   1 epochs, 2304.0 examples,9.91e-01 class acc,3.44e-02 bbox mae,47.7 examples/sec on cuda:0
#   1 epochs, 2432.0 examples,9.91e-01 class acc,3.40e-02 bbox mae,40.6 examples/sec on cuda:0
#   1 epochs, 2560.0 examples,9.90e-01 class acc,3.37e-02 bbox mae,46.9 examples/sec on cuda:0
#   1 epochs, 2688.0 examples,9.90e-01 class acc,3.34e-02 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 2816.0 examples,9.90e-01 class acc,3.30e-02 bbox mae,43.3 examples/sec on cuda:0
#   1 epochs, 2944.0 examples,9.90e-01 class acc,3.26e-02 bbox mae,48.2 examples/sec on cuda:0
#   1 epochs, 3072.0 examples,9.89e-01 class acc,3.23e-02 bbox mae,47.8 examples/sec on cuda:0
#   1 epochs, 3200.0 examples,9.89e-01 class acc,3.19e-02 bbox mae,45.0 examples/sec on cuda:0
#   1 epochs, 3328.0 examples,9.89e-01 class acc,3.15e-02 bbox mae,47.7 examples/sec on cuda:0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-17f0455b89aa> in <cell line: 1>()
# ----> 1 train(
#       2     net = net,
#       3     train_dataloader = train_dataloader,
#       4     optimizer = optimizer,
#       5     num_epochs = num_epochs,
#
# <ipython-input-15-77f5b64a6779> in train(net, train_dataloader, optimizer, num_epochs, device)
#      22
#      23             # 为每个锚框标注类别和偏移量
# ---> 24             bbox_labels, bbox_masks, cls_labels = bbox_assigner.multibox_target(anchors, Y)
#      25
#      26             # 根据类别和偏移量的预测和标注值计算损失函数
#
# /content/mydet/bbox/assigner.py in multibox_target(self, anchors, labels)
#      73             label = labels[i, :, :]
#      74             # 为每个锚框分配真实边界框
# ---> 75             anchors_bbox_map = self.assign_anchor_to_bbox(label[:, 1:], anchors)
#      76             # 为没有分配真实边界框的锚框分配背景类，即0类，具体做法是将其xmin、ymin、xmax、ymax坐标设为0
#      77             bbox_mask = ((anchors_bbox_map >= 0).float().unsqueeze(-1)).repeat(1, 4)
#
# /content/mydet/bbox/assigner.py in assign_anchor_to_bbox(self, ground_truth, anchors)
#      50             anchors_bbox_map[anc_idx] = box_idx
#      51             jaccard[:, box_idx] = col_discard
# ---> 52             jaccard[anc_idx, :] = row_discard
#      53
#      54         return anchors_bbox_map
#
# KeyboardInterrupt:

# %%
torch.save(net,'resnet50_fpn_ssd.pth')

# %%
net2 = torch.load('resnet50_fpn_ssd.pth',map_location=device)

# %%
net2
# Out:
# R50_FPN_SSD(
#   (backbone): Backbone(
#     (resnet): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=2048, out_features=1000, bias=True)
#     )
#   )
#   (neck): Neck(
#     (lateral_convs): ModuleList(
#       (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (fpn_convs): ModuleList(
#       (0-3): 4 x Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (head): Head(
#     (cls_convs): ModuleList(
#       (0-4): 5 x Sequential(
#         (0): Conv2d(256, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (reg_convs): ModuleList(
#       (0-4): 5 x Sequential(
#         (0): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
# )
