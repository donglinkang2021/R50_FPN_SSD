# %%
import torch
import numpy as np
from PIL import Image
import random
import torchvision.transforms as transforms

# %%
# 使用示例
img = Image.open('image/cat.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x180 at 0x247A1D2D580>

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Resize((256, 256))
])

# %%
transforms.ToPILImage()(transform(img))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x247A1D2D610>
